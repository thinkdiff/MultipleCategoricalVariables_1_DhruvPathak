# %%
import pandas as pd

# %%
data = {
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female', 'Male'],
    'Department': ['HR', 'IT', 'Finance', 'IT', 'Finance', 'HR'],
    'Satisfaction': ['High', 'Low', 'High', 'Low', 'Low', 'High']
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Gender Department Satisfaction
# 0    Male         HR         High
# 1  Female         IT          Low
# 2  Female    Finance         High
# 3    Male         IT          Low
# 4  Female    Finance          Low
# 5    Male         HR         High

# %%
pd.crosstab(index=[df['Gender'], df['Department']], columns=df['Satisfaction'])
# Out:
# Satisfaction       High  Low
# Gender Department
# Female Finance        1    1
#        IT             0    1
# Male   HR             2    0
#        IT             0    1
